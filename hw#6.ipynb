# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Save config information
# Out:
# 644

# %%
#print(cities)

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []
test = "London"
url = "http://api.openweathermap.org/data/2.5/weather?"
i = 1 
for city in cities:
        query_url = url + "appid=" + api_key + "&q=" + city
        response = requests.get(query_url)
        weatherjson = response.json()
        #lat = json['coord']['lat']
        #lat.append(json['coord']['lat'])
        #print(query_url)
        #print(f'Lat for {city} is {lat}')
        #print(city)
        #print(lat)
        #weatherjson
        print(f' Processing Record {i} | {city}')
        i = i + 1 
        #city_record = response["name"]
        #print(json)
        #print(city)
        #country_code = city.country_code
        #name = city.city_name
        #print(f"The city of {name.title()} is in '{country_code.upper()}'.")
        #print(city.windspeed)
    # try and except not working    
    #except:
        #print("Skipped")
    #continue
    
#lat
# Out:
#  Processing Record 1 | tiznit
#  Processing Record 2 | dingle
#  Processing Record 3 | shache
#  Processing Record 4 | comodoro rivadavia
#  Processing Record 5 | saleaula
#  Processing Record 6 | belushya guba
#  Processing Record 7 | punta arenas
#  Processing Record 8 | mmathubudukwane
#  Processing Record 9 | liusha
#  Processing Record 10 | fairbanks
#  Processing Record 11 | puerto ayora
#  Processing Record 12 | samalaeulu
#  Processing Record 13 | lebu
#  Processing Record 14 | bealanana
#  Processing Record 15 | upernavik
#  Processing Record 16 | esperance
#  Processing Record 17 | nefteyugansk
#  Processing Record 18 | alakurtti
#  Processing Record 19 | mataura
#  Processing Record 20 | karaul
#  Processing Record 21 | kapaa
#  Processing Record 22 | tres arroyos
#  Processing Record 23 | mumford
#  Processing Record 24 | avarua
#  Processing Record 25 | kavaratti
#  Processing Record 26 | barranca
#  Processing Record 27 | katsuura
#  Processing Record 28 | saldanha
#  Processing Record 29 | busselton
#  Processing Record 30 | tiksi
#  Processing Record 31 | rikitea
#  Processing Record 32 | bredasdorp
#  Processing Record 33 | samarai
#  Processing Record 34 | yanam
#  Processing Record 35 | sarangani
#  Processing Record 36 | paita
#  Processing Record 37 | mys shmidta
#  Processing Record 38 | grand river south east
#  Processing Record 39 | ushuaia
#  Processing Record 40 | bilma
#  Processing Record 41 | manono
#  Processing Record 42 | bilibino
#  Processing Record 43 | tuatapere
#  Processing Record 44 | chuy
#  Processing Record 45 | conde
#  Processing Record 46 | yinchuan
#  Processing Record 47 | taolanaro
#  Processing Record 48 | vaini
#  Processing Record 49 | husavik
#  Processing Record 50 | vestmannaeyjar
#  Processing Record 51 | atuona
#  Processing Record 52 | tazovskiy
#  Processing Record 53 | half moon bay
#  Processing Record 54 | qaanaaq
#  Processing Record 55 | turayf
#  Processing Record 56 | port elizabeth
#  Processing Record 57 | hualmay
#  Processing Record 58 | butaritari
#  Processing Record 59 | lorengau
#  Processing Record 60 | albany
#  Processing Record 61 | georgetown
#  Processing Record 62 | faanui
#  Processing Record 63 | wahran
#  Processing Record 64 | port hedland
#  Processing Record 65 | alofi
#  Processing Record 66 | voh
#  Processing Record 67 | golden
#  Processing Record 68 | teya
#  Processing Record 69 | cape town
#  Processing Record 70 | morondava
#  Processing Record 71 | yerbogachen
#  Processing Record 72 | port-gentil
#  Processing Record 73 | ambatolampy
#  Processing Record 74 | hilo
#  Processing Record 75 | gat
#  Processing Record 76 | illoqqortoormiut
#  Processing Record 77 | mar del plata
#  Processing Record 78 | norwich
#  Processing Record 79 | daru
#  Processing Record 80 | attawapiskat
#  Processing Record 81 | birao
#  Processing Record 82 | rawson
#  Processing Record 83 | talnakh
#  Processing Record 84 | kuito
#  Processing Record 85 | bogandinskiy
#  Processing Record 86 | te anau
#  Processing Record 87 | chelmza
#  Processing Record 88 | soligalich
#  Processing Record 89 | bambous virieux
#  Processing Record 90 | dikson
#  Processing Record 91 | ngukurr
#  Processing Record 92 | olafsvik
#  Processing Record 93 | bethel
#  Processing Record 94 | vysokogornyy
#  Processing Record 95 | srikakulam
#  Processing Record 96 | kaitangata
#  Processing Record 97 | barentsburg
#  Processing Record 98 | kimbe
#  Processing Record 99 | ixtapa
#  Processing Record 100 | port hardy
#  Processing Record 101 | hermanus
#  Processing Record 102 | nguiu
#  Processing Record 103 | new norfolk
#  Processing Record 104 | petropavlovsk-kamchatskiy
#  Processing Record 105 | marcona
#  Processing Record 106 | tuktoyaktuk
#  Processing Record 107 | santa isabel
#  Processing Record 108 | honggang
#  Processing Record 109 | tasiilaq
#  Processing Record 110 | namibe
#  Processing Record 111 | east london
#  Processing Record 112 | rio bananal
#  Processing Record 113 | spearfish
#  Processing Record 114 | aklavik
#  Processing Record 115 | nawabganj
#  Processing Record 116 | nizhnyaya tavda
#  Processing Record 117 | bluff
#  Processing Record 118 | bathsheba
#  Processing Record 119 | monywa
#  Processing Record 120 | tual
#  Processing Record 121 | shimoda
#  Processing Record 122 | klaksvik
#  Processing Record 123 | killybegs
#  Processing Record 124 | saint-philippe
#  Processing Record 125 | yellowknife
#  Processing Record 126 | chokurdakh
#  Processing Record 127 | schleiden
#  Processing Record 128 | resistencia
#  Processing Record 129 | hobart
#  Processing Record 130 | vechta
#  Processing Record 131 | penzance
#  Processing Record 132 | port antonio
#  Processing Record 133 | samusu
#  Processing Record 134 | wewak
#  Processing Record 135 | camacha
#  Processing Record 136 | severo-kurilsk
#  Processing Record 137 | griffith
#  Processing Record 138 | la paz centro
#  Processing Record 139 | gillette
#  Processing Record 140 | ancud
#  Processing Record 141 | san andres
#  Processing Record 142 | touros
#  Processing Record 143 | port alfred
#  Processing Record 144 | nanakuli
#  Processing Record 145 | lakhdenpokhya
#  Processing Record 146 | castro
#  Processing Record 147 | rapid valley
#  Processing Record 148 | verkhnevilyuysk
#  Processing Record 149 | bacuit
#  Processing Record 150 | katiola
#  Processing Record 151 | victoria
#  Processing Record 152 | san policarpo
#  Processing Record 153 | vaitape
#  Processing Record 154 | vavuniya
#  Processing Record 155 | nizhneyansk
#  Processing Record 156 | saskylakh
#  Processing Record 157 | poum
#  Processing Record 158 | port lincoln
#  Processing Record 159 | manmad
#  Processing Record 160 | berlevag
#  Processing Record 161 | saint-joseph
#  Processing Record 162 | buguruslan
#  Processing Record 163 | airai
#  Processing Record 164 | vaitupu
#  Processing Record 165 | matay
#  Processing Record 166 | wulanhaote
#  Processing Record 167 | laguna
#  Processing Record 168 | rincon
#  Processing Record 169 | minot
#  Processing Record 170 | maxixe
#  Processing Record 171 | amderma
#  Processing Record 172 | carutapera
#  Processing Record 173 | pokhara
#  Processing Record 174 | san jose
#  Processing Record 175 | ostrovnoy
#  Processing Record 176 | lufilufi
#  Processing Record 177 | keningau
#  Processing Record 178 | fevralsk
#  Processing Record 179 | alcaniz
#  Processing Record 180 | ndele
#  Processing Record 181 | lagoa
#  Processing Record 182 | ponta do sol
#  Processing Record 183 | shingu
#  Processing Record 184 | cidreira
#  Processing Record 185 | ilulissat
#  Processing Record 186 | lavrentiya
#  Processing Record 187 | kuche
#  Processing Record 188 | kununurra
#  Processing Record 189 | nhulunbuy
#  Processing Record 190 | sur
#  Processing Record 191 | bandarbeyla
#  Processing Record 192 | jamestown
#  Processing Record 193 | thompson
#  Processing Record 194 | salekhard
#  Processing Record 195 | punta alta
#  Processing Record 196 | malindi
#  Processing Record 197 | dandong
#  Processing Record 198 | salalah
#  Processing Record 199 | avera
#  Processing Record 200 | torbay
#  Processing Record 201 | uchiza
#  Processing Record 202 | caravelas
#  Processing Record 203 | pevek
#  Processing Record 204 | porto uniao
#  Processing Record 205 | skjervoy
#  Processing Record 206 | havelock
#  Processing Record 207 | krasnoarmeysk
#  Processing Record 208 | lata
#  Processing Record 209 | los llanos de aridane
#  Processing Record 210 | kyshtovka
#  Processing Record 211 | sao filipe
#  Processing Record 212 | cabo san lucas
#  Processing Record 213 | dhandhuka
#  Processing Record 214 | tigil
#  Processing Record 215 | isangel
#  Processing Record 216 | glubokoe
#  Processing Record 217 | abalak
#  Processing Record 218 | ouegoa
#  Processing Record 219 | clyde river
#  Processing Record 220 | mandera
#  Processing Record 221 | juifang
#  Processing Record 222 | grindavik
#  Processing Record 223 | nokaneng
#  Processing Record 224 | hithadhoo
#  Processing Record 225 | manbij
#  Processing Record 226 | hambantota
#  Processing Record 227 | kaeo
#  Processing Record 228 | takoradi
#  Processing Record 229 | segezha
#  Processing Record 230 | codrington
#  Processing Record 231 | longyearbyen
#  Processing Record 232 | kiama
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\pythondata\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-16ba14e671ae> in <module>
#      12 for city in cities:
#      13         query_url = url + "appid=" + api_key + "&q=" + city
# ---> 14         response = requests.get(query_url)
#      15         weatherjson = response.json()
#      16         #lat = json['coord']['lat']
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\pythondata\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\envs\pythondata\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\pythondata\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\pythondata\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
url2 = "http://api.openweathermap.org/data/2.5/weather?"
city2 = "London"
# Build query URL
query_url2 = url2 + "appid=" + api_key + "&q=" + city
response = requests.get(query_url2)
json2 = response.json()
json2["coord"]["lon"]

# %%
json2
